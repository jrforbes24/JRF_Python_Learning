# %%
import numpy as np

# %%
# Creating array of ones, but with differing dtypes
int_ones = np.ones((3,3), dtype = np.int8)
int_ones
# Out:
# array([[1, 1, 1],
#        [1, 1, 1],
#        [1, 1, 1]], dtype=int8)

# %%
int_ones.dtype
# Out:
# dtype('int8')

# %%
float_ones = np.ones((2, 2), dtype = np.float16)
float_ones
# Out:
# array([[1., 1.],
#        [1., 1.]], dtype=float16)

# %%
int_ones[1, 1] = -1
int_ones
# Out:
# array([[ 1,  1,  1],
#        [ 1, -1,  1],
#        [ 1,  1,  1]], dtype=int8)

# %%
uint_ones[1, 1] = -1
uint_ones
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-85e1559cc62b> in <module>()
# ----> 1 uint_ones[1, 1] = -1
#       2 uint_ones
#
# NameError: name 'uint_ones' is not defined

# %%
999 ** 999
# Out:
# ...

# %%
vec3 = np.array([999], dtype=np.float64)
vec3
# Out:
# array([999.])

# %%
vec3[0] ** vec3[0]
# Out:
# C:\Users\johnr\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: RuntimeWarning: overflow encountered in double_scalars
#   """Entry point for launching an IPython kernel.
# inf
